# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import scipy
import sklearn
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the dataset

# %%
df=pd.read_csv(r"C:\Users\Harshitha\Desktop\Data Trained\baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# We have 30 rows and 17 Columns

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# No null values are present

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# ERA is of float dtype whereas the rest are integers

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# The standard deviation looks high

# %%
corr=df.corr()
corr
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(14,10))
sns.heatmap(corr,annot=True)
plt.title("Correlation Map")
plt.show()

# %% [markdown]
# - We can observe that columns like "R","2B","BB","SHO", and "SV" are highly correlated with the target column which means these columns have very strong impact on the values of the target columns
# - Columns like "3B","SO","HR","H",and "CG" are normally correlated with the target column .
# - Rest of the columns are very less correlated with target columns and subsequently have negative values with the target columns

# %% [markdown]
# ## Splitting into X and Y

# %%
x=df.drop('W',axis=1)
y=df['W']

# %% [markdown]
# ## Checking for Skewness and Outliers

# %%
for i in df.columns:
    plt.subplots()
    sns.distplot(df[i],bins = 10, color = 'g',label = i)

# %%
for i in df.columns:
    plt.subplots()
    sns.boxplot(df[i])

# %% [markdown]
# - From the above Distplot, we can see that there is no skewness in the data
# - From the above box plot, we can see that there are outliers only in 'E' column. But not much

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# ## Machine Learning model training

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# Checking for best random state

# %%
le=LinearRegression()

# %%
maxAcc=0
maxRS=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    le.fit(x_train,y_train)
    pred=le.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print('best r2_score:',maxAcc,'with random_state:',maxRS)
# Out:
# best r2_score: 0.8603360666735208 with random_state: 34

# %% [markdown]
# We can see that the best random State is 34 with an 86% r2_score. So, we will use this random state to train the mode

# %% [markdown]
# ## Splitting the data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=34)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %% [markdown]
# ### Linear Regression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print('r2_score of le is:',r2_score(y_test,predlr))
print('mean_squared_error:',mean_squared_error(y_test,predlr))
print('mean_absolute_error:',mean_absolute_error(y_test,predlr))
print('root_mean_squared_error',np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# r2_score of le is: 0.8603360666735208
# mean_squared_error: 17.7045588567443
# mean_absolute_error: 2.8688844670400186
# root_mean_squared_error 4.207678559104093

# %% [markdown]
# ### Decision Tree Regressor

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
pred_dt=dt.predict(x_test)
print('r2_score of le is:',r2_score(y_test,pred_dt))
print('mean_squared_error:',mean_squared_error(y_test,pred_dt))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_dt))
print('root_mean_squared_error',np.sqrt(mean_squared_error(y_test,pred_dt)))
# Out:
# r2_score of le is: 0.017432800934943482
# mean_squared_error: 124.55555555555556
# mean_absolute_error: 9.666666666666666
# root_mean_squared_error 11.160446028522138

# %% [markdown]
# ### SVR

# %%
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
print('r2_score of le is:',r2_score(y_test,pred_svr))
print('mean_squared_error:',mean_squared_error(y_test,pred_svr))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_svr))
print('root_mean_squared_error',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# r2_score of le is: -0.0231322330187278
# mean_squared_error: 129.6977996127938
# mean_absolute_error: 9.18004861054236
# root_mean_squared_error 11.38849417670281

# %% [markdown]
# ### Random Forest Regressor

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
pred_rf=rf.predict(x_test)
print('r2_score of le is:',r2_score(y_test,pred_rf))
print('mean_squared_error:',mean_squared_error(y_test,pred_rf))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_rf))
print('root_mean_squared_error',np.sqrt(mean_squared_error(y_test,pred_rf)))
# Out:
# r2_score of le is: 0.43343106739384507
# mean_squared_error: 71.82135555555554
# mean_absolute_error: 6.915555555555555
# root_mean_squared_error 8.474748111628779

# %% [markdown]
# We can see that only LinearRegression is providing the best r2_score of 86%, DecisionTreeRegressor is showing 0.2%, SVR is providing negative score and Random Forest Regressor is showing 43%. So there may be underfitting in DecisionTree and SVR may be overfitting in LinearRegression. Hence we will go with regularization.

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %% [markdown]
# ### Lasso Regression

# %%
lt=Lasso(alpha=0.001)
lt.fit(x_train,y_train)
lt.score(x_train,y_train)
pred_ls=ls.predict(x_test)
print(r2_score(y_test,pred_ls))
print('mean_squared_error:',mean_squared_error(y_test,pred_ls))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_ls))
print('root_mean_squared_error',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# 0.8559470333126203
# mean_squared_error: 18.260936567234744
# mean_absolute_error: 3.075690948697747
# root_mean_squared_error 4.273281709323029

# %% [markdown]
# ### Ridge Regression

# %%
rd=Ridge(alpha=0.001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_rd=rd.predict(x_test)
print(r2_score(y_test,pred_rd))
print('mean_squared_error:',mean_squared_error(y_test,pred_rd))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_rd))
print('root_mean_squared_error',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# 0.8502544758080046
# mean_squared_error: 18.982556079054433
# mean_absolute_error: 3.0900905858944125
# root_mean_squared_error 4.356897529097331

# %% [markdown]
# ### Elastic Net Regression

# %%
en=ElasticNet(alpha=10)
en.fit(x_train,y_train)
en.score(x_train,y_train)
pred_en=en.predict(x_test)
print(r2_score(y_test,pred_en))
print('mean_squared_error:',mean_squared_error(y_test,pred_en))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_en))
print('root_mean_squared_error',np.sqrt(mean_squared_error(y_test,pred_en)))
# Out:
# 0.8559470333126203
# mean_squared_error: 18.260936567234744
# mean_absolute_error: 3.075690948697747
# root_mean_squared_error 4.273281709323029

# %% [markdown]
# Observations: We can see that regularization is providing 85% of accuracy with all three Lasso, Ridge, and ElasticNet. So ElasticNet is providing the best r2_score with fewer errors. So we will save this data.

# %% [markdown]
# ## Saving the data

# %%
import joblib

# %%
joblib.dump(ls,'basball.pkl')
# Out:
# ['basball.pkl']
